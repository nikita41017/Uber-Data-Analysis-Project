# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("UberDataset.csv")

# %%
dataframe.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NaN
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
dataframe.shape
# Out:
# (1156, 7)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  1156 non-null   object
#  1   END_DATE    1155 non-null   object
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %% [markdown]
# # Data preprocessing

# %%
dataframe['PURPOSE'].fillna("NOT", inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14436\2094015869.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataframe['PURPOSE'].fillna("NOT", inplace = True)

# %%
dataframe.head()
# Out:
#          START_DATE          END_DATE  CATEGORY        START             STOP  \
# 0  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce      Fort Pierce
# 1  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce      Fort Pierce
# 2  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES          PURPOSE
# 0    5.1   Meal/Entertain
# 1    5.0              NOT
# 2    4.8  Errand/Supplies
# 3    4.7          Meeting
# 4   63.7   Customer Visit

# %%
dataframe['START_DATE'] = pd.to_datetime(dataframe['START_DATE'],errors ='coerce')
dataframe['END_DATE'] = pd.to_datetime(dataframe['END_DATE'],errors ='coerce')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   START_DATE  421 non-null    datetime64[ns]
#  1   END_DATE    420 non-null    datetime64[ns]
#  2   CATEGORY    1155 non-null   object
#  3   START       1155 non-null   object
#  4   STOP        1155 non-null   object
#  5   MILES       1156 non-null   float64
#  6   PURPOSE     1156 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(4)
# memory usage: 63.3+ KB

# %%
from datetime import datetime

dataframe['date'] =pd.DatetimeIndex(dataframe['START_DATE']).date
dataframe['time'] =pd.DatetimeIndex(dataframe['START_DATE']).hour

# %%
dataframe.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0

# %%
dataframe['day-night']= pd.cut(x=dataframe['time'],bins = [0,10,15,19,24],labels =['morning','Afternoon','Evening','Night'])

# %%
dataframe.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  dat-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    day-night
# 0      Night
# 1    morning
# 2      Night
# 3    Evening
# 4  Afternoon

# %%
dataframe.dropna(inplace = True)

# %%
dataframe.shape
# Out:
# (413, 10)

# %% [markdown]
# DATA VISUALIZATION

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.countplot(dataframe['CATEGORY'])
plt.xticks(rotation=90)

plt.subplot(1,2,2)
sns.countplot(dataframe['PURPOSE'])
# Out:
# <Axes: xlabel='count', ylabel='PURPOSE'>

# %%
sns.countplot(dataframe['day-night'])
# Out:
# <Axes: xlabel='count', ylabel='day-night'>

# %%
dataframe['MONTH'] = pd.DatetimeIndex(dataframe['START_DATE']).month

month_label = {1.0: 'jan', 2.0: 'feb' , 3.0: 'Mar', 4.0: 'april',
               5.0: 'may', 6.0: 'june', 7.0: 'july', 8.0: 'aug',
               9.0: 'sep', 10.0: 'oct', 11.0: 'nov', 12.0: 'dec'}
dataframe["MOUTH"]= dataframe.MONTH.map(month_label)
mon= dataframe.MONTH.value_counts(sort=False)

# %%
dataframe.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  dat-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    day-night  MONTH MOUTH
# 0      Night      1   jan
# 1    morning      1   jan
# 2      Night      1   jan
# 3    Evening      1   jan
# ...

# %%
dataframe = pd.DataFrame({
    "MONTHS" : mon.values,
    "VALUE COUNT": dataframe.groupby('MONTH', sort=False)['MILES'].max()
})
p= sns.lineplot(data =dataframe)
p.set (xlabel="MONTHS", ylabel="VALUE COUNT")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 3
#       1 dataframe = pd.DataFrame({
#       2     "MONTHS" : mon.values,
# ----> 3     "VALUE COUNT": dataframe.groupby('MONTH', sort=False)['	MILES'].max()
#       4 })
#       5 p= sns.lineplot(data =dataframe)
#       6 p.set (xlabel="MONTHS", ylabel="VALUE COUNT")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# ...

# %%
dataframe['DAY'] = dataframe. START_DATE.dt.weekday

day_label ={
    0: 'Mon', 1: 'tues', 2: 'wed', 3: 'thur', 4: 'fri', 5: 'sat', 6: 'sun'}
dataframe['DAY'] = dataframe['DAY'].map(day_label)

# %%
dataframe.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  dat-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    day-night  MONTH MOUTH   DAY
# 0      Night      1   jan   fir
# 1    morning      1   jan   sat
# 2      Night      1   jan   sat
# ...

# %%
day_label = dataframe.DAY.value_counts()

sns.barplot(x=day_label.index, y= day_label)
plt.xlabel('DAY')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
dataframe.head()
# Out:
#            START_DATE            END_DATE  CATEGORY        START  \
# 0 2016-01-01 21:11:00 2016-01-01 21:17:00  Business  Fort Pierce
# 1 2016-01-02 01:25:00 2016-01-02 01:37:00  Business  Fort Pierce
# 2 2016-01-02 20:25:00 2016-01-02 20:38:00  Business  Fort Pierce
# 3 2016-01-05 17:31:00 2016-01-05 17:45:00  Business  Fort Pierce
# 4 2016-01-06 14:42:00 2016-01-06 15:49:00  Business  Fort Pierce
#
#               STOP  MILES          PURPOSE        date  time  dat-night  \
# 0      Fort Pierce    5.1   Meal/Entertain  2016-01-01  21.0      Night
# 1      Fort Pierce    5.0              NOT  2016-01-02   1.0    morning
# 2      Fort Pierce    4.8  Errand/Supplies  2016-01-02  20.0      Night
# 3      Fort Pierce    4.7          Meeting  2016-01-05  17.0    Evening
# 4  West Palm Beach   63.7   Customer Visit  2016-01-06  14.0  Afternoon
#
#    day-night  MONTH MOUTH   DAY
# 0      Night      1   jan   fri
# 1    morning      1   jan   sat
# 2      Night      1   jan   sat
# ...

# %%
sns.boxplot(dataframe['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(dataframe[dataframe['MILES']<100]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.boxplot(dataframe[dataframe['MILES']<40]['MILES'])
# Out:
# <Axes: ylabel='MILES'>

# %%
sns.distplot(dataframe[dataframe['MILES']<40]['MILES'])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_14436\1456316812.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataframe[dataframe['MILES']<40]['MILES'])
# <Axes: xlabel='MILES', ylabel='Density'>
